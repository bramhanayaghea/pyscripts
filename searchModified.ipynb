# %%
import os
import pandas as pd
# Load in the input
df = pd.read_excel('C:\\Users\\inbra\\OneDrive - Software AG\\Documents\\Adda\\msc\\common\\TammJourney_2.xlsx')
# extract substring from column

substrings = df['API_Endpoint'].str.replace('^https://sgs\.api\.abudhabi\.ae/gateway/TammJourney[A-Za-z]+/2\.0/', '').tolist()
#print(substrings)
# Create a new column called 'present' and initialize it to False
df['present'] = False

# List of words to search for
search_words = ['eventLicensing/organizers/{id}','eventLicensing/organizers/validateContactMail/{contactMail}/{OrganizedID}','eventLicensing/v2/payment/getRecieptUrl','eventLicensing/event/{id}/venues','eventLicensing/sharedServices/vwTicketPaymentDetails','eventLicensing/event/{eventId}/paymentCallBack','eventLicensing/organizers/getSelfOrganizerByIdNoArea/{Id}','specialLicense/saveNoc','eventLicensing/participant/getById','eventLicensing/event/{id}/lineItems/eventApprovalStatusId','eventLicensing/draft/createEntertainerPermit','eventLicensing/entertainerPermit/{id}/invoices','eventLicensing/masterData/educationLevels','venueBooking/venueUpdatePayment','venueBooking/bookingEvents','specialLicense/specialLicenseByTradeLicense','artWorkshop/deleteOrder','venueBooking/venueBook','hotelLicensing/requests/{id}/payment','eventLicensing/category/{parentId}/childs','eventLicensing/companies/{id}','sso/linkSsoUser','specialLicense/specialLicenseMasterData','artWorkshop/productAvailability','eventLicensing/userNotifications/updateIsRead','eventLicensing/event/workFlow','eventLicensing/userNotifications/count','venueBooking/venueAvailability','artWorkshop/onboardUser','eventLicensing/survey/type','eventLicensing/sponsors','eventLicensing/notifications/{id}','eventLicensing/organizers/getSelfOrganizerProfileStatusCount/{emiratesId}','specialLicense/nocList','eventLicensing/entertainerPermit/permitsListing/count','eventLicensing/organizers/validateCompanyTL/{tlNumber}','specialLicense/specialLicenseProfile','sso/otp','eventLicensing/draft/{id}/delete','eventLicensing/sharedServices/eventTermsAndConditions','hotelLicensing/requests','eventLicensing/draft/entertainerPermit','eventLicensing/organizers/getSelfOrganizerById/{Id}','eventLicensing/organizers/delinkUser','eventLicensing/organizers','eventLicensing/participant/{id}','eventLicensing/participant/submit','hotelLicensing/classificationTypes/{id}','eventLicensing/event/eventsListing/count','hotelLicensing/classificationTypes','venues/{id}','eventLicensing/draft/participant','specialLicense/document','eventLicensing/v2/emailParticipant/sendParticipaintOtp','touristGuideLicensing/registration/licenseEligibility','eventLicensing/participant/sendInvitiationsByEmail','events/getEventDetails','venueBooking/venueCancel','eventLicensing/companies/venusView/count','specialLicense/nocDetails','specialLicense/payment/invoice/{id}','hotelLicensing/requests/{id}/paymentCallBack','specialLicense/temparoryLicenseList','artWorkshop/productDetails','eventLicensing/organizers/removeContact/{contactID}','venueBooking/token','hotelLicensing/hotelLicenseTermsAndConditions/{id}','venueBooking/venueExtend','hotelLicensing/requests/{id}/accounts/type/{id2}','eventLicensing/draft/venue','eventLicensing/event/amend','artWorkshop/productLocations','eventLicensing/organizers/listUsers/count','hotelLicensing/accountTypes','eventLicensing/v2/payment/downloadReceipt','specialLicense/circular','hotelLicensing/hotelLicenseRegions','eventLicensing/masterData/genders','eventLicensing/token','hotelLicensing/common/disclaimer/{id}','eventLicensing/entertainerPermit/{id}/paymentApprovalStatus','venueBooking/venuebooking','venueBooking/bookingEvent','eventLicensing/masterData/userTypes','eventLicensing/participant','eventLicensing/masterData/permitType','eventLicensing/event/{id}/permitStatus','eventLicensing/mstrAreaCategory','eventLicensing/v2/emailParticipant/verifyOtp','eventLicensing/organizers/addContact','eventLicensing/masterData/shapes','venueBooking/venueAmend','artWorkshop/reservationDetails','eventLicensing/draft/entertainerPermit/count','eventLicensing/organizers/addUserForOrganizer','eventLicensing/v2/event/{eventId}/invoices','eventLicensing/organizers/businessLicense','eventLicensing/entertainerPermit/{id}/paymentCallBack','eventLicensing/v2/emailParticipant/verifyToken','eventLicensing/event/getEvent/{id}','venueBooking/eventsAudiences','eventLicensing/event/{id}/cancel','eventLicensing/category/fullCategoryName/{categoryId}','events/getEvents','eventLicensing/mstrParticipantType','eventLicensing/event/{id}','eventLicensing/event/{id}/comments','venues','artWorkshop/createOrder','hotelLicensing/requests/{id}/attachments','eventLicensing/companies/venusView','specialLicense/payment/paymentCallBack/{id}','eventLicensing/entertainerPermit/ammentComment','hotelLicensing/requests/{id}/facilities','eventLicensing/organizers/getSelfOrganizerProfileStatus/{emiratesId}','hotelLicensing/requests/{id}/attachmentTypes','eventLicensing/masterData/permitActivity','artWorkshop/productList','venueBooking/termsConditions','eventLicensing/sharedServices/fileContent','eventLicensing/masterData/notificationCategory','sso/v2/ssoUserDetails','eventLicensing/userNotifications/getAllNoAttachment','hotelLicensing/requests/{id}/accounts/{id2}','eventLicensing/event/submit','eventLicensing/organizers/validateContactMail/{contactMail}','token','eventLicensing/organizers/getSelfOrganizercount/{emiratesId}','hotelLicensing/requests/{id}/submit','artWorkshop/orderVoucher','eventLicensing/masterData/visaTypes','eventLicensing/masterData/professions','hotelLicensing/createHotelLicenseRequest','eventLicensing/masterData/marketingCategories','eventLicensing/organizers/validateCompanyTL/{tlNumber}/{OrganizedID}','hotelLicensing/requests/{id}/projectdetails','eventLicensing/draft/{id}/{entityName}','specialLicense/token','eventLicensing/venueCities','eventLicensing/participant/count','eventLicensing/v2/sharedServices/vwPaymentDetails','eventLicensing/organizers/listUsers','hotelLicensing/unitGroups','eventLicensing/masterData/religions','eventLicensing/sharedServices/entertainmentPermitTermsAndConditions','eventLicensing/organizers/validateCompanyName/{companyName}','eventLicensing/sharedServices/getActionNotificationByUserId','venueBooking/venueUserProfile','eventLicensing/venueCities/all','eventLicensing/entertainerPermit/{id}/cancel','eventLicensing/organizers/getSelfOrganizer/{userName}','eventLicensing/organizers/submit','artWorkshop/updateReservation','hotelLicensing/classificationTypes/{id}/ratings','artWorkshop/createAwInvoice','venueBooking/venueUserProfilePost','eventLicensing/participant/emailValid','artWorkshop/token','sso/modifySsoUserDetails','venueBooking/rentalFees','artWorkshop/productOrderDetails','eventLicensing/countries','eventLicensing/sharedServices/vwTicketPaymentDetails/count','eventLicensing/organizers/validateUserAssociation','eventLicensing/v2/emailParticipant/expireToken','artWorkshop/artWorkShopOrders','events/token','eventLicensing/masterData/permitIssuePeriod','hotelLicensing/requests/{id}/accounts','eventLicensing/entertainerPermit/{id}/permitVoucherViewModel','eventLicensing/organizersView','eventLicensing/organizers/validateCompanyName/{companyName}/{organizedID}','artWorkshop/createReservation','hotelLicensing/unitGroups/{id}/UnitTypes','eventLicensing/entertainerPermit/{id}','eventLicensing/survey/questions','eventLicensing/v2/areaList/shapes','specialLicense/temparoryLicense','eventLicensing/sharedServices/vwPaymentDetails','eventLicensing/sharedServices/roleSections','eventLicensing/participant/passportValid','eventLicensing/activities','eventLicensing/file','touristGuideLicensing/token','venueBooking/venueInfo','eventLicensing/entertainerPermit/submit','specialLicense/specialLicenseVenues','eventLicensing/draft/createEvent','eventLicensing/sharedServices/updateActionNotification','eventLicensing/masterData/socialNetworkType','sso/v3/ssoUserDetails','eventLicensing/draft/event','eventLicensing/sharePoint/getTaskItemStatus','eventLicensing/survey/submit','eventLicensing/draft/event/count','eventLicensing/masterData/passportTypes','hotelLicensing/attachmentTypes','venueBooking/eventTypes','hotelLicensing/token','specialLicense/saveDocument','eventLicensing/masterData/nationalities','eventLicensing/marketing/getByEventId/{id}','eventLicensing/draft/venue/count','venueBooking/organizationTypes','eventLicensing/participant/emiratesIdValid','eventLicensing/entertainerPermit/{id}/approvalStatus/{approvalStatusId}','eventLicensing/entertainerPermit/workFlow','eventLicensing/masterData/speakerLanguages','eventLicensing/organizationCategories','eventLicensing/attachments/byCode/{code}','sso/createSsoUser','venueBooking/venueApplication','venueBooking/venueApplicationDetail','eventLicensing/organizers/{id}/isEligibleForApply','eventLicensing/venue/submit','eventLicensing/entertainerPermit/amend','hotelLicensing/permits','hotelLicensing/requests/{id}/status','venueBooking/emirates','eventLicensing/organizersView/count','eventLicensing/organizers/setAdminUser','hotelLicensing/requests/{id}','eventLicensing/category','eventLicensing/entertainerPermit/permitsListing','artWorkshop/updateAwInvoice','eventLicensing/event/eventsListing','eventLicensing/sharedServices/pdfLicense','eventLicensing/licenseType','artWorkshop/updateOrder','eventLicensing/participant/amend/{id}','eventLicensing/countries/{id}/cities','artWorkshop/profiles/{id}','artWorkshop/productCategories','eventLicensing/entertainerPermit/{id}/renew','eventLicensing/v2/entertainerPermit/{permitId}/invoices','eventLicensing/companies/area/{id}','sso/token','eventLicensing/draft/participant/count','eventLicensing/entertainerPermit/{permitId}/getApproved','hotelLicensing/requests/{id}/permit','venueBooking/venueEvents','hotelLicensing/accountTypes/{id}']
search_strings = ['hotelLicensing/accountTypes/{id}']
search_strings1 = ['touristGuideLicensing/token','token']

# Directory path to search in
dir_path = 'C:\\JDeveloper\\mywork\\Adda_Prod\\TammMicroservices'

def search_for_string_in_pipeline_files(directory, search_string):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith((".pipeline",".xqy", ".js")):
                file_lower = file.lower()
                search_parts = search_string.lower().split('/')
                search_string_lower = search_parts[0]
                     
                if search_string_lower in file_lower:
                    for ext in [".xqy", ".js"]:
                        matching_files = [f for f in files if f.endswith(ext) and search_parts[0] in f.lower()]
                        for matching_file in matching_files:
                            with open(os.path.join(root, matching_file), "r") as f:
                                for line in f:
                                    if search_parts[1].lower() in line.lower():
                                        print(matching_file+line+search_string)
                                        return True
    return False
def search_files1(start_dir, search_string):
    search_parts = search_string.lower().split('/')
    for root, dirs, files in os.walk(start_dir):
        # Search for .pipeline files
        for file in files:
            
            if file.lower().endswith(('.pipeline','.xqy', '.js')) and search_parts[0] in file.lower():
                pipeline_file_path = os.path.join(root, file)
                if search_parts[1] in ('', '{}'):
                    search_term = 'undefined'
                else:
                    search_term = search_parts[1].lower()
                # Search for .xqy and .js files with the first word in the filename
                for ext in ('.xqy', '.js'):
                    for file2 in files:
                        
                        if file2.lower().endswith(ext) and search_parts[0] in file2.lower():
                            file2_path = os.path.join(root, file2)
                            # Read the contents of the .xqy or .js file
                            with open(file2_path, 'r') as f:
                                file2_contents = f.read()
                                # Split the file contents into individual words
                                words = file2_contents.lower().split()
                                # Check if the search string is in any of the words
                                if any(search_term.lower() in word for word in words):
                                    print(file2_path + ": " + search_term)
                                    return True

def search_files(start_dir, search_string):
    search_parts = search_string.lower().split('/')
    for root, dirs, files in os.walk(start_dir):
        # Search for .pipeline, .xqy, and .js files
        for file in files:
            if file.lower().endswith(('.pipeline', '.xqy', '.js')) and search_parts[0] in file.lower():
                file_path = os.path.join(root, file)
                if len(search_parts) > 1 and search_parts[1] not in ('', '{'):
                    search_term = search_parts[1].lower()
                    
                else:
                    search_term = 'undefined'
                if file.lower().endswith(('.xqy','.js')):
                    # Search for the search term in the contents of the xqy or js file
                    with open(file_path, 'r') as f:
                        file_contents = f.read()
                    if search_term in file_contents.lower():
                        print(file_path + ": " + search_term)
                        return True
# Out:
# C:\Users\inbra\AppData\Local\Temp\ipykernel_25504\2057663720.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   substrings = df['API_Endpoint'].str.replace('^https://sgs\.api\.abudhabi\.ae/gateway/TammJourney[A-Za-z]+/2\.0/', '').tolist()

# %%
for substring in substrings:
    
    mask = df['API_Endpoint'].str.contains(substring , case=False) 
    if mask.any():
        # If the string is present, call the function with the string as argument
        result=search_files(dir_path,substring)
        print (result)
        if result==True:
            # If the function returns a value, update the 'present' column to True
            
            df.loc[mask, 'present'] = True
# Save the updated dataframe to a new Excel file
df.to_excel('C:\\Users\\inbra\\OneDrive - Software AG\\Documents\\Adda\\msc\\common\\result.xlsx', index=False)
# Out:
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\SCAD\Resources\StoreItems\utilities\ruleFile\StoreItemsRoutingRules.xqy: getoutlets
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\SCAD\Resources\StoreItems\utilities\ruleFile\StoreItemsRoutingRules.xqy: getstoreitemsprices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\SCAD\Resources\StoreItems\utilities\ruleFile\StoreItemsRoutingRules.xqy: getregions
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\SDI\MapServices\Resources\MapServicesSDIReq.js: generatetoken
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: downloaddoc
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getinspectioncategory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getlistofdocumment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getinspectionform
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getplotdatafromdiffsystem
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getmepsprojectstepsallmunc
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getinspectionsdatabyplotallmun
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getdataofworkflow
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getreports
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: uploaddocument
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: gethowmanydays
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: loadnocforplotallmun
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: submitinspection
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: getplotxyallmunc
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\AACM\qassimiti\Resources\utilities\ruleFile\qassimitiRoutingRules.xqy: gettashweendata
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\eventServies\Resources\TammJourneyAdcciEventServiesResp.js: undefined
# True
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: falcondetailssave
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: submitapplication
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: gethuntingzones
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: deleteuploadedfile
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: uploadfile
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: getapplicationlistfornoc
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: falcondetailsupdate
# True
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: validateapplication
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: downloadlicense
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: documentlist
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: insertapplication
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: createnocapplication
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: updateapplication
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: getfalconsdetailslist
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: aquacultureapplicationinformationselect
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: aquaculturerenewapplicationlistselect
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: aquaculturecontactinformationupdate
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: getapplication
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: getuserlicenses
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: submitapplication
# True
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: getapplication
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: downloadtreetranslocationcompletioncertificate
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\AquacultureCustomer\Resources\AquacultureCustomerReq.js: aquaculturedraftapplicationsubmit
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: gethuntingseasons
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: falcondetailsdelete
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: getfalcondetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\FalconryCustomer\Resources\FalconryCustomerReq.js: downloadlicense
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: downloadtranslocationpermit
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\EAD\TreeTranlocation\Resources\TreeTranslocationEADReq.js: createapplication
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\WasteTransportationVehiclePermit\utilities\ruleFile\WasteTransportationVehiclePermitRoutingRules.xqy: getpermitlist
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\WasteTransportationVehiclePermit\utilities\ruleFile\WasteTransportationVehiclePermitRoutingRules.xqy: getpermitdetails
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: istrafficcoderequired
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\LACService\utilities\ruleFile\LACServiceRoutingRules.xqy: viewlacdetailsresponse
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: createsubuser
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\OutsideEmirates\utilities\ruleFile\OutsideEmiratesServiceRoutingRules.xqy: addoutsideemirates
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: hasmanageuserspermission
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: iswastereductionrequired
# True
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: submitrenewaccount
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\VehicleService\utilities\ruleFile\VehicleServiceRoutingRules.xqy: removevehicle
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\OutsideEmirates\utilities\ruleFile\OutsideEmiratesServiceRoutingRules.xqy: viewoutsideemiratedetails
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\BalanceService\utilities\ruleFile\BalanceServiceRoutingRules.xqy: submitaddbalance
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: getwmlicensedocumentdetails
# True
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: submitremoveuser
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\VehicleService\utilities\ruleFile\VehicleServiceRoutingRules.xqy: viewaddremovevehilcedetails
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: getwastereductionrequirment
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: getnocdocumentdetails
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\BalanceService\utilities\ruleFile\BalanceServiceRoutingRules.xqy: getbalancehistory
# True
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\VehicleService\utilities\ruleFile\VehicleServiceRoutingRules.xqy: isinspectionrequired
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\VehicleService\utilities\ruleFile\VehicleServiceRoutingRules.xqy: addvehicle
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: isehsrequired
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\LACService\utilities\ruleFile\LACServiceRoutingRules.xqy: addlacapplication
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: registeronlineuser
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\OutsideEmirates\utilities\ruleFile\OutsideEmiratesServiceRoutingRules.xqy: getwasteproducer
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: disableuser
# True
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: isinspectionrequired
# True
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\RenewService\utilities\ruleFile\RenewServiceRoutingRules.xqy: viewrenewdetails
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: registernewaccount
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\CWM\Resources\ProfileManagementService\utilities\ruleFile\ProfileManagementServiceRoutingRules.xqy: getuserdocuments
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: mba
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: getlookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oba
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: downloadattachment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: getlicensemetadata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: getngolicenselist
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oce
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oba
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oba
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: mba
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: uploadattachment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oce
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: mba
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: noc
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: getlicensedetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: noc
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: deleteattachment
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: mba
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oba
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: getattachmenttypes
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: oce
# True
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DCD\Resources\scripts\NGO\DcdNGORequestMapping.js: noc
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADM\SmartHub\cancelPowerOfAttorney\Resources\utilities\cancelPowerOfAttorneyReq.js: common
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ZHO\Resources\Lookups\utilities\transform\ZhoLookupsJsonResponseMapping.js: undefined
# True
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: invitewifeconsentaction
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: baytidesigns
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: getattestationcertificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: swapprimarywithcoapplicant
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\UnderTakingJsonRequestMapping.js: checkandget
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: invitewifeconsent
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: appointment
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: invitestatusenquiry
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: initiateconfirmdata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: generaltext
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: appointment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: onlineconsultation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: questionnaire
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\Resources\Scripts\MustasharakJsonRequestMapping.js: appointment
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: invitenewapplicant
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADFCA\common\Resources\utilities\deleteRegistrationRequestByEidReq.xqy: query
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: inviteresponse
# True
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADHA\DigitalServices\Resources\utilities\ruleFile\ADHADigitalServices.xqy: invitewifestatusenquiry
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\inspectionsAndViolationsDashboard\utilities\ruleFile\inspectionsAndViolationsDashboardRouting.xqy: getinspections
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: saveeprequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: getcustomsprofile
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getattachments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: submitbordercrosspermit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\requestsDashboard\utilities\ruleFile\requestsDashboardRouting.xqy: getksadeclaration
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: getcompprofileupdatestatus
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: getservicedocumentexcel
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: showconsignmentdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: requestsubmitcashdeclaration
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: validateeligibledepositvoucherrefund
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: submitissuanceofrepresentativecard
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: validaterenewalonbehalf
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\requestsDashboard\utilities\ruleFile\requestsDashboardRouting.xqy: getallrequests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: getservicescnrattachments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customsBilling\utilities\ruleFile\customsBillingRouting.xqy: getpermitnumber
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: updateuserbyagent
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: updatecompanyinfobyadmin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: validatedeclarationnumber
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\reportsDashboard\utilities\ruleFile\reportsDashboardRouting.xqy: submitavailablereport
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: getrestrictauthoritylistv2
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getalerts
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getdepositvouchertoextend
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: submiteprequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: pullattachments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: getalluserrequests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getcirculations
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: search
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: geteligtransbalconsolidated
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: retrieveeligibledeposits
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getguidelines
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getdelegationslist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\freeZoneDeclaration\utilities\ruleFile\freeZoneDeclarationRouting.xqy: getfzbalances
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getprofilecenters
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: gettrabrochureattseq
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getrefundeligibilityaccount
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: requestrenewaldeposit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\charterDashboard\utilities\ruleFile\charterDashboardRouting.xqy: getcharterdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: geteprequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: getapplicationreferencenumberv3
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\charterDashboard\utilities\ruleFile\charterDashboardRouting.xqy: updatecharterdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: gettraequipmentcategories
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: submitrenewimporternumber
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getinformationalerts
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: getfacilitiesaccounts
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getuserprofile
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: explanatorychapter
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: gettraserialattseq
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: getshipmentlist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\inspectionsAndViolationsDashboard\utilities\ruleFile\inspectionsAndViolationsDashboardRouting.xqy: getviolationsbyno
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: createsinglejob
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: tree
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getsurveysinformation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getservicemaintenanceinfo
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\reportsDashboard\utilities\ruleFile\reportsDashboardRouting.xqy: getreportslist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: updatemaincompanyapproval
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getprofileinfo
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: chapterdata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: searchdeclarationimporter
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customerCare\utilities\ruleFile\customerCareRouting.xqy: getcertificatetype
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: getimporterdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilitiesServiceDetails\utilities\ruleFile\utilitiesServiceDetailsRouting.xqy: getserviceattachments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: searchallimporters
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: retrieveapplicationdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: requestduplicatecustomcard
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getsubtype
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customerCare\utilities\ruleFile\customerCareRouting.xqy: submitrequestfortruecopycertificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getunreadalertcount
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: processfeepayment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: getuserbyadmin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: validatedepositextvoucher
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: submitissueimporter
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: sealnumberlist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: uploadattachment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customsCertificate\utilities\ruleFile\customsCertificateRouting.xqy: getconsoldepositamount
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getcashdisclosureamount
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\reportsDashboard\utilities\ruleFile\reportsDashboardRouting.xqy: getdocumentbyid
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: getcompanybycode
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: checkexistingrequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: history
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getfinaloutputdocuments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: getagentrating
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: issueimporteram
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customsCertificate\utilities\ruleFile\customsCertificateRouting.xqy: submitconsolidatedcert
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getvisualcharts
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: checkpaymentrecord
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\refundManagement\utilities\ruleFile\refundManagementRouting.xqy: submitdepositrefundrequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: gettemplatelist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\requestsDashboard\utilities\ruleFile\requestsDashboardRouting.xqy: pickksadeclaration
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getprivatewarehouses
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: submitforbrokerpermit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilitiesServiceDetails\utilities\ruleFile\utilitiesServiceDetailsRouting.xqy: getcustomsprofile
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: getfacilitybalance
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getdrafts
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: checkeligibleprofileimp
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: updateuserbyadmin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: getnewsupdates
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getcustomsprofilev3
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\circulationsAnnouncementsDashboard\utilities\ruleFile\circulationsAnnouncementsDashboardRouting.xqy: gettemplates
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\intellectualPropertyManagement\utilities\ruleFile\intellectualPropertyManagementRouting.xqy: submitrequesttrademarkreg
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: submitupdatedeletebill
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: pushattachments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\profileManagementDashboard\utilities\ruleFile\profileManagementDashboardRouting.xqy: getusereligibletammservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\refundManagement\utilities\ruleFile\refundManagementRouting.xqy: submitdutyrefundrequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: getrestrictauthoritylist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getfeaturestra
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customsCertificate\utilities\ruleFile\customsCertificateRouting.xqy: submitnobillcert
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getcompanycardlist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customerCare\utilities\ruleFile\customerCareRouting.xqy: submitcertificaterequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsPrivateWarehouseDeclaration\utilities\ruleFile\adCustomsPrivateWarehouseDeclaration.xqy: getpwgoodsorigin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: idbpayment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\inspectionsAndViolationsDashboard\utilities\ruleFile\inspectionsAndViolationsDashboardRouting.xqy: getviolationslist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\requestsDashboard\utilities\ruleFile\requestsDashboardRouting.xqy: getrequestinfo
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getfacilitytypes
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getservicedocument
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: gettemplatefieldvisible
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getimpvisiblefields
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: submitcashdeclaration
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\charterDashboard\utilities\ruleFile\charterDashboardRouting.xqy: getchartercontent
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: updatealertstatus
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcSmartClassificationSystem\utilities\ruleFile\adcSmartClassificationRouting.xqy: tariffbook
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: getservicedocumentpdf
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: submitupdcompdata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\utilityDashboard\utilities\ruleFile\utilityDashboardRouting.xqy: getuserroles
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: validatedeclarationeligibility
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: renewalcustomcard
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adCustomsGenericServices\utilities\adCustomsGenericServicesRules.xqy: getlookupdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\processUtility\utilities\ruleFile\processUtilityRouting.xqy: createorupdatepayment
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\custBillDeclaration\utilities\ruleFile\custBillDeclarationRouting.xqy: getapplicationreferencenumber
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\customsCertificate\utilities\ruleFile\customsCertificateRouting.xqy: geteligibilitycustomscert
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\importers\utilities\ruleFile\importersRouting.xqy: checktradelicenseimp
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\adcAdhocService\utilities\ruleFile\adcAdhocServiceRouting.xqy: submitlicenseprwc
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCUSTOMS\Resources\borderCrossingSystem\utilities\ruleFile\borderCrossingSystemRouting.xqy: downloadpermitbyreqid
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADP\Resources\utilities\activityService\activityServiceRequest.js: undefined
# True
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: permitamendments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: retrievemultistoreyschoolbussr
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: getdocumentlist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: retrieveviolationdetailscommercial
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: managevehicleservice
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: createdetrminationpermit
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesRes.js: grievance
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: createparkingservice
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: feedbackservice
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: retrivehistorycontact
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: createmultistoreyschoolbussr
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: retrievehistoryapplication
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: retieveincidentdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: mwallettopupbyweb
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: retrieveviolationdetailsschoolbus
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesReq.js: querydeterminationpermit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: paymentintegrationservice
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: determinationpermitvalidation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\CrmServices\Resources\utilities\CrmServicesRes.js: grievance
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: getappfee
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOT\crmServices\Resources\utilities\crmServicesReq.js: mwalletbalanceenquiry
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ITC\DarbIntegration\Resources\utilities\DarbIntegrationReq.js: publicservices
# True
# ...
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: getsendbackeditablefields
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: getservicedisclaimer
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: getspecificdocument
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: getspecificdocument
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: getsubservicecode
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: paylater
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: payrecordbalance
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: payrecordbalance
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: saverecorddata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: submitrecordandcalculatefees
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\records\recordsReq.js: validateandsavedata
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: checkuserexist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: createuser
# True
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: forgetpassword
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: forgetusername
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\rulesFile\userManagementRoutingRules.xqy: getlookup
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: getuserprofile
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: requestedrolesstatus
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: requestuserroles
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: updateuserprofile
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: userlogin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\Resources\UserManagement\utilities\ruleFile\userManagementRoutingRules.xqy: validatepasswordtoken
# True
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOF\Resources\publicTenders\utilities\ruleFile\PublicTenderRules.xqy: getpublictenderdetails
# True
# None
# None
# None
# None
# None
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\DOH\AccelaServices\Resources\scripts\healthAdvert\DohAccelaHealthAdvertJsonRequestMapping.js: undefined
# True
# None
# None
# None
# None
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: create
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: mobdiahapplication
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: certificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: businessmancertificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: commercialdirectory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\eventServies\Resources\TammJourneyAdcciEventServiesReq.js: events
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: updatemobdiahdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\identityservices\Resources\TammJourneyAdcciIdentityReq.js: tammregister
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: resubmit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: account
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: certificateoforigin
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: commercialdirectory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: getmembershippricelist
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\consultancyServies\Resources\TammJourneyAdcciConsultancyReq.js: resubmit
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: getmobdiahapplication
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: counters
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\consultancyServies\Resources\TammJourneyAdcciConsultancyReq.js: upsert
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: newmembership
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: api
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: contractrequestdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: certificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: services
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: documents
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: payments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: commercialdirectory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: payments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: payments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: createcontract
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: towhomitmayconcern
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: services
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: attestation
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: getmembership
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: inquiry
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: certificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\consultancyServies\Resources\TammJourneyAdcciConsultancyReq.js: getrequestinfo
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: requestdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: services
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: gettammrequestdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: services
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: inquiry
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: adclegal
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: servicerequests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: nonmembership
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: documents
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: lookups
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: commercialdirectory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: getcompanywithdetails
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: certificate
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\adLockerDocs\Resources\TammJourneyAdcciAdLockerReq.js: mubdiah
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: documents
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: tasks
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: commercialdirectory
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: api
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\consultancyServies\Resources\TammJourneyAdcciConsultancyReq.js: closerequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: getaccountbylicensenumber
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: payments
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: documents
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\legalservices\Resources\TammJourneyAdcciLegalServicesReq.js: closecontractrequest
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: services
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: survey
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: user
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: inquiry
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\coreservices\Resources\TammJourneyAdcciCoreReq.js: requests
# True
# C:\JDeveloper\mywork\Adda_Prod\TammMicroservices\ADCCI\membershipservices\Resources\TammJourneyAdcciMembershipReq.js: certificate
# True
