# %%
import os
import pandas as pd
# Load in the input
df = pd.read_excel('C:\\Users\\inbra\\OneDrive - Software AG\\Documents\\Adda\\msc\\common\\TammJourney_2.xlsx')
# extract substring from column

substrings = df['API_Endpoint'].str.replace('^https://sgs\.api\.abudhabi\.ae/gateway/TammJourneyDct/2\.0', '').tolist()
#print(substrings)
# Create a new column called 'present' and initialize it to False
df['present'] = False

# List of words to search for
search_words = ['eventLicensing/organizers/{id}','eventLicensing/organizers/validateContactMail/{contactMail}/{OrganizedID}','eventLicensing/v2/payment/getRecieptUrl','eventLicensing/event/{id}/venues','eventLicensing/sharedServices/vwTicketPaymentDetails','eventLicensing/event/{eventId}/paymentCallBack','eventLicensing/organizers/getSelfOrganizerByIdNoArea/{Id}','specialLicense/saveNoc','eventLicensing/participant/getById','eventLicensing/event/{id}/lineItems/eventApprovalStatusId','eventLicensing/draft/createEntertainerPermit','eventLicensing/entertainerPermit/{id}/invoices','eventLicensing/masterData/educationLevels','venueBooking/venueUpdatePayment','venueBooking/bookingEvents','specialLicense/specialLicenseByTradeLicense','artWorkshop/deleteOrder','venueBooking/venueBook','hotelLicensing/requests/{id}/payment','eventLicensing/category/{parentId}/childs','eventLicensing/companies/{id}','sso/linkSsoUser','specialLicense/specialLicenseMasterData','artWorkshop/productAvailability','eventLicensing/userNotifications/updateIsRead','eventLicensing/event/workFlow','eventLicensing/userNotifications/count','venueBooking/venueAvailability','artWorkshop/onboardUser','eventLicensing/survey/type','eventLicensing/sponsors','eventLicensing/notifications/{id}','eventLicensing/organizers/getSelfOrganizerProfileStatusCount/{emiratesId}','specialLicense/nocList','eventLicensing/entertainerPermit/permitsListing/count','eventLicensing/organizers/validateCompanyTL/{tlNumber}','specialLicense/specialLicenseProfile','sso/otp','eventLicensing/draft/{id}/delete','eventLicensing/sharedServices/eventTermsAndConditions','hotelLicensing/requests','eventLicensing/draft/entertainerPermit','eventLicensing/organizers/getSelfOrganizerById/{Id}','eventLicensing/organizers/delinkUser','eventLicensing/organizers','eventLicensing/participant/{id}','eventLicensing/participant/submit','hotelLicensing/classificationTypes/{id}','eventLicensing/event/eventsListing/count','hotelLicensing/classificationTypes','venues/{id}','eventLicensing/draft/participant','specialLicense/document','eventLicensing/v2/emailParticipant/sendParticipaintOtp','touristGuideLicensing/registration/licenseEligibility','eventLicensing/participant/sendInvitiationsByEmail','events/getEventDetails','venueBooking/venueCancel','eventLicensing/companies/venusView/count','specialLicense/nocDetails','specialLicense/payment/invoice/{id}','hotelLicensing/requests/{id}/paymentCallBack','specialLicense/temparoryLicenseList','artWorkshop/productDetails','eventLicensing/organizers/removeContact/{contactID}','venueBooking/token','hotelLicensing/hotelLicenseTermsAndConditions/{id}','venueBooking/venueExtend','hotelLicensing/requests/{id}/accounts/type/{id2}','eventLicensing/draft/venue','eventLicensing/event/amend','artWorkshop/productLocations','eventLicensing/organizers/listUsers/count','hotelLicensing/accountTypes','eventLicensing/v2/payment/downloadReceipt','specialLicense/circular','hotelLicensing/hotelLicenseRegions','eventLicensing/masterData/genders','eventLicensing/token','hotelLicensing/common/disclaimer/{id}','eventLicensing/entertainerPermit/{id}/paymentApprovalStatus','venueBooking/venuebooking','venueBooking/bookingEvent','eventLicensing/masterData/userTypes','eventLicensing/participant','eventLicensing/masterData/permitType','eventLicensing/event/{id}/permitStatus','eventLicensing/mstrAreaCategory','eventLicensing/v2/emailParticipant/verifyOtp','eventLicensing/organizers/addContact','eventLicensing/masterData/shapes','venueBooking/venueAmend','artWorkshop/reservationDetails','eventLicensing/draft/entertainerPermit/count','eventLicensing/organizers/addUserForOrganizer','eventLicensing/v2/event/{eventId}/invoices','eventLicensing/organizers/businessLicense','eventLicensing/entertainerPermit/{id}/paymentCallBack','eventLicensing/v2/emailParticipant/verifyToken','eventLicensing/event/getEvent/{id}','venueBooking/eventsAudiences','eventLicensing/event/{id}/cancel','eventLicensing/category/fullCategoryName/{categoryId}','events/getEvents','eventLicensing/mstrParticipantType','eventLicensing/event/{id}','eventLicensing/event/{id}/comments','venues','artWorkshop/createOrder','hotelLicensing/requests/{id}/attachments','eventLicensing/companies/venusView','specialLicense/payment/paymentCallBack/{id}','eventLicensing/entertainerPermit/ammentComment','hotelLicensing/requests/{id}/facilities','eventLicensing/organizers/getSelfOrganizerProfileStatus/{emiratesId}','hotelLicensing/requests/{id}/attachmentTypes','eventLicensing/masterData/permitActivity','artWorkshop/productList','venueBooking/termsConditions','eventLicensing/sharedServices/fileContent','eventLicensing/masterData/notificationCategory','sso/v2/ssoUserDetails','eventLicensing/userNotifications/getAllNoAttachment','hotelLicensing/requests/{id}/accounts/{id2}','eventLicensing/event/submit','eventLicensing/organizers/validateContactMail/{contactMail}','token','eventLicensing/organizers/getSelfOrganizercount/{emiratesId}','hotelLicensing/requests/{id}/submit','artWorkshop/orderVoucher','eventLicensing/masterData/visaTypes','eventLicensing/masterData/professions','hotelLicensing/createHotelLicenseRequest','eventLicensing/masterData/marketingCategories','eventLicensing/organizers/validateCompanyTL/{tlNumber}/{OrganizedID}','hotelLicensing/requests/{id}/projectdetails','eventLicensing/draft/{id}/{entityName}','specialLicense/token','eventLicensing/venueCities','eventLicensing/participant/count','eventLicensing/v2/sharedServices/vwPaymentDetails','eventLicensing/organizers/listUsers','hotelLicensing/unitGroups','eventLicensing/masterData/religions','eventLicensing/sharedServices/entertainmentPermitTermsAndConditions','eventLicensing/organizers/validateCompanyName/{companyName}','eventLicensing/sharedServices/getActionNotificationByUserId','venueBooking/venueUserProfile','eventLicensing/venueCities/all','eventLicensing/entertainerPermit/{id}/cancel','eventLicensing/organizers/getSelfOrganizer/{userName}','eventLicensing/organizers/submit','artWorkshop/updateReservation','hotelLicensing/classificationTypes/{id}/ratings','artWorkshop/createAwInvoice','venueBooking/venueUserProfilePost','eventLicensing/participant/emailValid','artWorkshop/token','sso/modifySsoUserDetails','venueBooking/rentalFees','artWorkshop/productOrderDetails','eventLicensing/countries','eventLicensing/sharedServices/vwTicketPaymentDetails/count','eventLicensing/organizers/validateUserAssociation','eventLicensing/v2/emailParticipant/expireToken','artWorkshop/artWorkShopOrders','events/token','eventLicensing/masterData/permitIssuePeriod','hotelLicensing/requests/{id}/accounts','eventLicensing/entertainerPermit/{id}/permitVoucherViewModel','eventLicensing/organizersView','eventLicensing/organizers/validateCompanyName/{companyName}/{organizedID}','artWorkshop/createReservation','hotelLicensing/unitGroups/{id}/UnitTypes','eventLicensing/entertainerPermit/{id}','eventLicensing/survey/questions','eventLicensing/v2/areaList/shapes','specialLicense/temparoryLicense','eventLicensing/sharedServices/vwPaymentDetails','eventLicensing/sharedServices/roleSections','eventLicensing/participant/passportValid','eventLicensing/activities','eventLicensing/file','touristGuideLicensing/token','venueBooking/venueInfo','eventLicensing/entertainerPermit/submit','specialLicense/specialLicenseVenues','eventLicensing/draft/createEvent','eventLicensing/sharedServices/updateActionNotification','eventLicensing/masterData/socialNetworkType','sso/v3/ssoUserDetails','eventLicensing/draft/event','eventLicensing/sharePoint/getTaskItemStatus','eventLicensing/survey/submit','eventLicensing/draft/event/count','eventLicensing/masterData/passportTypes','hotelLicensing/attachmentTypes','venueBooking/eventTypes','hotelLicensing/token','specialLicense/saveDocument','eventLicensing/masterData/nationalities','eventLicensing/marketing/getByEventId/{id}','eventLicensing/draft/venue/count','venueBooking/organizationTypes','eventLicensing/participant/emiratesIdValid','eventLicensing/entertainerPermit/{id}/approvalStatus/{approvalStatusId}','eventLicensing/entertainerPermit/workFlow','eventLicensing/masterData/speakerLanguages','eventLicensing/organizationCategories','eventLicensing/attachments/byCode/{code}','sso/createSsoUser','venueBooking/venueApplication','venueBooking/venueApplicationDetail','eventLicensing/organizers/{id}/isEligibleForApply','eventLicensing/venue/submit','eventLicensing/entertainerPermit/amend','hotelLicensing/permits','hotelLicensing/requests/{id}/status','venueBooking/emirates','eventLicensing/organizersView/count','eventLicensing/organizers/setAdminUser','hotelLicensing/requests/{id}','eventLicensing/category','eventLicensing/entertainerPermit/permitsListing','artWorkshop/updateAwInvoice','eventLicensing/event/eventsListing','eventLicensing/sharedServices/pdfLicense','eventLicensing/licenseType','artWorkshop/updateOrder','eventLicensing/participant/amend/{id}','eventLicensing/countries/{id}/cities','artWorkshop/profiles/{id}','artWorkshop/productCategories','eventLicensing/entertainerPermit/{id}/renew','eventLicensing/v2/entertainerPermit/{permitId}/invoices','eventLicensing/companies/area/{id}','sso/token','eventLicensing/draft/participant/count','eventLicensing/entertainerPermit/{permitId}/getApproved','hotelLicensing/requests/{id}/permit','venueBooking/venueEvents','hotelLicensing/accountTypes/{id}']
search_strings = ['hotelLicensing/accountTypes/{id}']
search_strings1 = ['token']

# Directory path to search in
dir_path = 'C:\\JDeveloper\\mywork\\Adda_Prod\\TammMicroservices'

def search_string_in_files(search_string, directory):
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if filename.endswith('.pipeline'):
                if search_string.lower() in filename.lower():
                    print(filename)
                    file_path = os.path.join(root, filename)
                    with open(file_path, 'r') as f:
                        for line in f:
                            #if line.endswith('.xqy\n') or line.endswith('.js\n'):
                                #print(line.strip())
                            print(line)
def search_for_string_in_pipeline_files(directory, search_string):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith((".pipeline",".xqy", ".js")):
                file_lower = file.lower()
                search_parts = substring.lower().split('/')
                search_string_lower = search_parts[0]
                     
                if search_string_lower in file_lower:
                    for ext in [".xqy", ".js"]:
                        
                        matching_files = [f for f in files if f.endswith(ext) and search_parts[0] in f.lower()]
                        for matching_file in matching_files:
                            with open(os.path.join(root, matching_file), "r") as f:
                                for line in f:
                                    #print(search_parts[1]+line)
                                    if search_parts[1].lower() in line.lower():
                                        
                                        print(matching_file+line+substring)
                                        return True
return False
# Out:
# C:\Users\inbra\AppData\Local\Temp\ipykernel_24788\3664327424.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   substrings = df['API_Endpoint'].str.replace('^https://sgs\.api\.abudhabi\.ae/gateway/TammJourneyDct/2\.0', '').tolist()

# %%
for substring in substrings:
    searchurl = 'https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0' + substring
    print(searchurl)
    mask = df['API_Endpoint'].str.contains(substring , case=False) 
    if mask.any():
        # If the string is present, call the function with the string as argument
        result=search_for_string_in_pipeline_files(dir_path,substring)
        print (result)
        if result==True:
            # If the function returns a value, update the 'present' column to True
            
            df.loc[mask, 'present'] = True
# Save the updated dataframe to a new Excel file
df.to_excel('C:\\Users\\inbra\\OneDrive - Software AG\\Documents\\Adda\\msc\\common\\result.xlsx', index=False)


    
# Loop through each row in the dataframe
#for index, row in df.iterrows():
    # Check if any of the search strings are in the column value
    #if any(search_string in row['API Endpoint'] for search_string in search_strings):
        #searchRes=search_for_string_in_pipeline_files(dir_path,substring)
        #if(len(searchRes>1)
            # If there is a match, update the 'match' column to True
            #df.at[index, 'match'] = True
# Out:
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyScad/2.0/storeItems/getOutlets
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyScad/2.0/storeItems/getStoreItemsPrices
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyScad/2.0/storeItems/getRegions
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyFazaa/2.0/membershipServices/fetchMemberByEmiratesId
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyFazaa/2.0/membershipServices/token
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyFazaa/2.0/membershipServices/register
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyFazaa/2.0/membershipServices/fetchMember
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/cfLegalTranslation/mapServer/{id}/query
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/genericSearch/mapServer/{id}/query
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/adpJourney/mapServer/{id}/query
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/cfBanks/mapServer/attachments/{id}/{attId}/attachments/{attachmentId}
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/manageYourFarms/mapServer/{id}/query
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/mapService/generateToken
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/cfLegalTranslation/mapServer/{id}
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/cfBanks/mapServer/{id}/query
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMap/2.0/adp/cfLegalTranslation/mapServer
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/downloadDoc
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getInspectionCategory
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getListOfDocumment
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getInspectionForm
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getPlotDataFromDiffSystem
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getMepsProjectStepsAllMunc
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getInspectionsDataByPlotAllMun
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getDataOfWorkflow
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getReports
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/uploadDocument
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getHowManyDays
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/loadNocForPlotAllMun
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/submitInspection
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/health
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getPlotXYAllMunc
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAacm/2.0/qassimiti/getTashweenData
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMaqta/2.0/site/{siteId}/events
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMaqta/2.0/events
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMaqta/2.0/site/{siteId}/events/{eventId}/attachment/{cId}
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyMaqta/2.0/action/site/{siteId}/events/{eventId}/acknowledge
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getToken/getToken
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getTawtheeqList/getTawtheeqList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getTawtheeqList/getTawtheeqListV4#!1
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getTawtheeqDetails/getTawtheeqDetailsV4
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getListOfConsultantsAndContractors/getListOfConsultantsAndContractors
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getTawtheeqDetails/getTawtheeqDetailsV4#!1
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/health
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyTawtheeq/2.0/getTawtheeqDetails/getTawtheeqDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAdx/2.0/publicServices/symbols
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyAdx/2.0/publicServices/summary
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/machineryDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fuelUsedSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fossilDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForProcessDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/wasteDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/decommissioningApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/updateWellDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/productDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getNewRegistrationList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/facilityStudyReportRequestsDetailsGet
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getModificationList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/updateProjectDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentAdministrativeDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getApplicationsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentAdministrativeDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/insertApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentTechnicalDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/falconDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/eqsQuestionnaireSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/validateApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/deleteTechnicalTeamsDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/rawMaterialUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/saveTechnicalSummary
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/hazardousMaterialUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getMachineryDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForOwners
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/uploadFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getCountries
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/deleteDraftApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/deleteProjectDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForFuelUsed
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/marineActivitiesDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getRawMaterials
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/updateTechnicalTeamsDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/downloadLicense
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getSectorCommunities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/marineActivitiesSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getCountries
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/nonCriticalQuestionnaireSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getProductionGoesTo
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/marineActivitiesUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/administrativeDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/validateCommissioningApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/wasteDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getLandOwnerType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/DigitalDocument/CommercialFishingLicense/getLicenseDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/processDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/processDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getUserCompanies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getRequestedReports
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getCommercialComissioning
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getSavedFieldOfWorksDropDown
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/technicalDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentAdministrativeDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/airEmissionDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getEQSApplicationHeader
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getHuntingZones
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getUsersProponentCompaniesGovernmentList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentActivityDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getAirEmissionDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getRegisteredCompaniesByLicenseNumber
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/airEmissionDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getLicenseIssuanceEntities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/groundWaterPlatePayment
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getPort
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getAdministrativeDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/deleteUploadedFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/machineryDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getBoatBodyType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/requiredDocumentsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/uploadFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/digitalDocument/recreationalFishingLicense/authenticateDigitalDocumentRequest
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/technicalModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getAuthorizedCompanies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/digitalDocument/recreationalFishingLicense/getLicenseDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/wasteDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/uploadFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/machineryDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getTypeOfActivities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getUnitsFromPhysicalStatus
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentActivityDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getCompaniesAuthorizedUsers
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/downloadLicense
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/getApplicationListForNOC
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getTechnicalDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getConsultantsForStudy
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/facilityStudyReportRequestsDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/falconDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getIndustrialDeComissioning
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForWaterUsage
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/processDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getMeasuringUnits
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fossilDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/machineryDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getTechnicalTeamsDetailsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/validateApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fossilDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/downloadLicense
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/documentList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getRequestedStudies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/insertApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getFuelUsed
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/hazardousMaterialSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getFarmsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/DigitalDocument/CommercialFishingLicense/authenticateDigitalDocumentRequest
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/deleteDocumentById
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/adminModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForRawMaterials
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/updateCompaniesAuthorizedUser
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getReissueReasons
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getGovernmentEntities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getIndustrialNew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fuelUsedUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getZones
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentRenew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/saveProjectDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/viewUploadedFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fossilDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/deleteUploadedFile
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForHazardousMaterial
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/hazardousMaterialDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForWasteType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForMarineActivities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/createNOCApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/administrativeDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/studyAndReportStatusUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getCommercialRenew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownData
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/marineActivitiesSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/getApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentActivityDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getProjectDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/decommissioningApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/facilityStudyReportRequestsGet
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/waterUsageDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsDevelopmentAdminDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/linkuserProfileWithGovernmentEntity
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getEQSFacilityDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/sectorQuestionnaireSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentActivityDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/updateApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForMachinery
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getMunicipalities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getFalconsDetailsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getIndustrialComissioning
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/saveTechnicalTeamsDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fuelUsedSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/facilityInspectionHistoryGet
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/aquacultureApplicationInformationSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsDevelopmentTechnicalDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/rawMaterialSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/downloadLicense
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getUnitsFromPowerSupplyType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/aquacultureRenewApplicationListSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/commissioningApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getSavedAdministrativeDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getStudyOrReportHistory
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/aquacultureContactInformationUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getCommercialNew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getWaterUsageDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/downloadPaymentReceipt
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/authentication/getUserToken
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getRenewalList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getSectorQuestions
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getEmirateStates
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentTechnicalDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getFieldsOfWorkDetailsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/linkuserProfileWithCompany
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/resubmitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/getCompanyByLicenseDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/commissioningApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/deleteDraftApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/geBasicFossilDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/updateApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/validateDecommissioningApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/getApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getLandOwnerType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getUserLicenses
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/getUploadedStudyDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getMarineActivity
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getApplicationCategory
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/wasteDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/studyReportUploadedDocumentsGet
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/administrativeDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/documentList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/questionnaireDocumentUpload
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/waterUsageDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/hazardousMaterialSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/deleteTechnicalActivities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getNonCriticalQuestions
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/renewApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/digitalDocument/recreationalFishingLicense/recreationalLicensesList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/applicationModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getWasteDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getWellLocationType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getEmirateCities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/waterUsageDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/rawMaterialSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getCommercialModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/insertApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/resubmitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/criticalQuestionnaireSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getAdministrativeDetailsFromIntegration
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDevelopmentNew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/administrativeDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getTechnicalDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/downloadTreeTranslocationCompletionCertificate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/technicalActivitiesSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/productDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/commercialAdministrativeDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/processDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/aquacultureCustomer/aquacultureDraftApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/saveFieldOfWorks
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCommon/activitiesSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/technicalActivitiesSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getHuntingSeasons
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getIndustrialModification
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getIndustrialRenew
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getFossilDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getTechnicalTeamsDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/validateApplicationSubmit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/waterUsageDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/ecoCustomer/getProjectDetailsList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/rawMaterialDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getCriticalQuestions
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/submitApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getTreeSpecies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/airEmissionDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/falconDetailsDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/airEmissionDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getEmirateCities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/commercialFishing/getLicenseNumbers
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/digitalServicesSSO/getMasterToken
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/productDetailsSelect
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/insertAuthorizedCompanies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/fuelUsedDelete
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/DigitalDocument/CommercialFishingLicense/getListLicenses
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/getDropdownsForAirEmission
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/industrialAdministrativeDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/developmentActivityDetailsUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/userProfile/updateAuthorizedCompanies
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/getFalconDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/falconryCustomer/downloadLicense
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/downloadTranslocationPermit
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/common/getBoatType
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/treeTranslocation/createApplication
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/eqsCustomer/productDetailsSave
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/rasidInspection/facilityStudyReportResponseUpdate
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyEad/2.0/groundWater/getLicenseDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/lookupService/getWasteTypesMaterials
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/wasteTransportationVehiclePermit/getPermitList
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/constructionAndDemolitionService/submitConstruction
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/applicationService/validateRenewActivities
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/lookupService/getBalanceSlots
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/accountService/getAccountSubUsers
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/financeService/getExportOutOfEmirateFees
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/wasteTransportationVehiclePermit/getPermitDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/foodDisposalService/addFoodDisposal
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/constructionAndDemolitionService/viewCnDDetails
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/renewService/isTrafficCodeRequired
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/lacService/viewLACDetailsResponse
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/financeService/getAddActivitiesFees
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/constructionAndDemolitionService/getAsbestosTransporter
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/financeService/getRenewFees
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/profileManagementService/createSubUser
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/outsideEmiratesService/addOutsideEmirates
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/profileManagementService/hasManageUsersPermission
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0https://sgs.api.abudhabi.ae/gateway/TammJourneyCwm/2.0/renewService/isWasteReductionRequired
# None
# ...
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/SpecialLicenseServicePS</service>
# /specialLicense/token
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/venueCities
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/venueCities
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/participant/count
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/participant/count
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/v2/sharedServices/vwPaymentDetails
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/v2/sharedServices/vwPaymentDetails
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/listUsers
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/listUsers
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/unitGroups
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/HotelLicensingPS</service>
# /hotelLicensing/unitGroups
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/masterData/religions
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/masterData/religions
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/entertainmentPermitTermsAndConditions
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/entertainmentPermitTermsAndConditions
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/validateCompanyName/{companyName}
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/validateCompanyName/{companyName}
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/getActionNotificationByUserId
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/getActionNotificationByUserId
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/venueBooking/venueUserProfile
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/VenueBooking_PS</service>
# /venueBooking/venueUserProfile
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/venueCities/all
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/venueCities/all
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/entertainerPermit/{id}/cancel
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/entertainerPermit/{id}/cancel
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/getSelfOrganizer/{userName}
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/getSelfOrganizer/{userName}
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/submit
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/submit
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/updateReservation
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/updateReservation
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/classificationTypes/{id}/ratings
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/HotelLicensingPS</service>
# /hotelLicensing/classificationTypes/{id}/ratings
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/createAwInvoice
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/createAwInvoice
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/venueBooking/venueUserProfilePost
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/VenueBooking_PS</service>
# /venueBooking/venueUserProfilePost
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/participant/emailValid
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/participant/emailValid
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/token
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/token
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/sso/modifySsoUserDetails
# ActvetCrmErrorHandling.jsvar keysSorted = Object.keys(process.body).sort(function(a,b){return});
# /sso/modifySsoUserDetails
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/venueBooking/rentalFees
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/VenueBooking_PS</service>
# /venueBooking/rentalFees
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/productOrderDetails
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/productOrderDetails
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/countries
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/countries
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/vwTicketPaymentDetails/count
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/vwTicketPaymentDetails/count
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/validateUserAssociation
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/validateUserAssociation
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/v2/emailParticipant/expireToken
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/v2/emailParticipant/expireToken
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/artWorkShopOrders
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/artWorkShopOrders
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/events/token
# TammJourneyAdcciEventServiesReq.jsprocess.serviceName = 'TAMM-ESB/ADCCI/ProxyServices/ADCCIEvents_APIPS';
# /events/token
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/masterData/permitIssuePeriod
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/masterData/permitIssuePeriod
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/requests/{id}/accounts
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/HotelLicensingPS</service>
# /hotelLicensing/requests/{id}/accounts
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/entertainerPermit/{id}/permitVoucherViewModel
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/entertainerPermit/{id}/permitVoucherViewModel
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizersView
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizersView
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/organizers/validateCompanyName/{companyName}/{organizedID}
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/organizers/validateCompanyName/{companyName}/{organizedID}
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/artWorkshop/createReservation
# ArtWorkshopRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/ArtWorkshopServicePS</service>
# /artWorkshop/createReservation
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/unitGroups/{id}/UnitTypes
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/HotelLicensingPS</service>
# /hotelLicensing/unitGroups/{id}/UnitTypes
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/entertainerPermit/{id}
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/entertainerPermit/{id}
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/survey/questions
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/survey/questions
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/v2/areaList/shapes
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/v2/areaList/shapes
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/specialLicense/temparoryLicense
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/SpecialLicenseServicePS</service>
# /specialLicense/temparoryLicense
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/vwPaymentDetails
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/vwPaymentDetails
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/roleSections
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/roleSections
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/participant/passportValid
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/participant/passportValid
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/activities
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/activities
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/file
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/file
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/touristGuideLicensing/token
# None
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/venueBooking/venueInfo
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/VenueBooking_PS</service>
# /venueBooking/venueInfo
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/entertainerPermit/submit
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/entertainerPermit/submit
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/specialLicense/specialLicenseVenues
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/SpecialLicenseServicePS</service>
# /specialLicense/specialLicenseVenues
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/draft/createEvent
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/draft/createEvent
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharedServices/updateActionNotification
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharedServices/updateActionNotification
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/masterData/socialNetworkType
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/masterData/socialNetworkType
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/sso/v3/ssoUserDetails
# ActvetCrmErrorHandling.jsvar keysSorted = Object.keys(process.body).sort(function(a,b){return});
# /sso/v3/ssoUserDetails
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/draft/event
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/draft/event
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/sharePoint/getTaskItemStatus
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/sharePoint/getTaskItemStatus
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/survey/submit
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/survey/submit
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/draft/event/count
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/draft/event/count
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/eventLicensing/masterData/passportTypes
# EventLicensingMessageRequest.jsprocess.serviceName = 'TAMM-ESB/DCT/ProxyService/DCTEventLicensingServicePS';
# /eventLicensing/masterData/passportTypes
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/attachmentTypes
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/HotelLicensingPS</service>
# /hotelLicensing/attachmentTypes
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/venueBooking/eventTypes
# HotelLicenseRoutingRules.xqy                <service>TAMM-ESB/DCT/ProxyService/VenueBooking_PS</service>
# /venueBooking/eventTypes
# True
# https://sgs.api.abudhabi.ae/gateway/TammJourneyDct2.0/hotelLicensing/token
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[134], line 7
#       4 mask = df['API_Endpoint'].str.contains(substring , case=False)
#       5 if mask.any():
#       6     # If the string is present, call the function with the string as argument
# ----> 7     result=search_for_string_in_pipeline_files(dir_path,substring)
#       8     print (result)
#       9     if result==True:
#      10         # If the function returns a value, update the 'present' column to True
#
# Cell In[133], line 46, in search_for_string_in_pipeline_files(directory, search_string)
#      44 for matching_file in matching_files:
#      45     with open(os.path.join(root, matching_file), "r") as f:
# ---> 46         for line in f:
#      47             #print(search_parts[1]+line)
#      48             if search_parts[1].lower() in line.lower():
#      50                 print(matching_file+line+substring)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\encodings\cp1252.py:22, in IncrementalDecoder.decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# KeyboardInterrupt:
