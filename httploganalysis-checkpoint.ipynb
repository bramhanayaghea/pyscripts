# %%
import os
import re
from fnmatch import fnmatch
from collections import defaultdict

# Specify the directory to search
search_directory = "C:\\Users\\inbra\\OneDrive - Software AG\\Documents\\Adda\\go-live\\3108-2023"

# Define a dictionary to store counts
url_counts = defaultdict(lambda: {"200": 0, "non-200": []})

# Function to process http.log files
def process_http_log_file(file_path):
    with open(file_path, 'r') as f:
        log_lines = f.readlines()

    for line in log_lines:
        # Find the position of the first date string
        date_match = re.search(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}', line)
        if date_match:
            date_start = date_match.start()
            remaining_part = line[date_start:]
            
            # Split the remaining part into columns
            columns = remaining_part.split()

            if len(columns) >= 7:
                url = columns[3]  # URL is at index 3
                response_code = columns[4]  # Response code is at index 4
                
                # Ignore the last part of the URL if it contains numbers
                url_parts = url.split('/')
                if url_parts[-1].isdigit():
                    url = '/'.join(url_parts[:-1])
                
                if response_code == "200":
                    url_counts[url]["200"] += 1
                else:
                    message = line.strip()  # Entire line as the message
                    url_counts[url]["non-200"].append(message)

# Recursively search for http.log files in the directory and its subdirectories
for root, dirs, files in os.walk(search_directory):
    for file in files:
        if fnmatch(file, "http*.log"):
            file_path = os.path.join(root, file)
            process_http_log_file(file_path)

# Print the results
for url, counts in url_counts.items():
    count_200 = counts["200"]
    count_non_200 = len(counts["non-200"])  # Count of non-200 responses
    non_200_messages = counts["non-200"]
    
    print(f"URL: {url}")
    print(f"Count of 200 responses: {count_200}")
    print(f"Count of Non-200 responses: {count_non_200}")
    print(f"Non-200 responses:")
    for message in non_200_messages:
        print(message)
    print("-" * 30)
# Out:
# URL: /invoke/wm.server/ping
# Count of 200 responses: 318023
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_CPC.rs:MarsoomAPIPS/adhaMarsoom
# Count of 200 responses: 240
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /
# Count of 200 responses: 11598
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices
# Count of 200 responses: 28612
# Count of Non-200 responses: 42
# Non-200 responses:
# "151.253.124.9, 10.254.69.150" 2023-09-01 00:06:30 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:4e2850c6-e8ff-4d3d-bb65-02b09b9201e7:175069 8203 493
# "151.253.124.9, 10.254.69.155" 2023-09-01 07:53:56 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:856eaf07-d4bc-4383-a693-266293c9e59c:180116 92 493
# "151.253.124.9, 10.254.69.148" 2023-09-01 08:03:05 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:4d305c0a-5408-4e66-bea4-f054cca29878:168983 7830 493
# "151.253.124.9, 10.254.69.150" 2023-09-01 08:12:58 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:5133f3c6-e7f7-49ff-b1b4-788e7c6c01ee:178631 8596 493
# "151.253.124.9, 10.254.69.151" 2023-09-01 08:17:56 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:5cb77b07-cce5-4319-9c13-ced050fc8f39:180093 9616 493
# "151.253.124.9, 10.254.69.151" 2023-09-01 08:18:43 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:3f62ee9b-e5c1-4194-8678-368de428627f:180124 11406 493
# "151.253.124.9, 10.254.69.146" 2023-09-01 08:27:52 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:84ad30a5-8da4-4ffe-a3d4-0ee2b3cf648d:172225 4721 493
# "151.253.124.9, 10.254.69.157" 2023-09-01 09:02:38 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:0a5737f2-f380-4336-a5ce-5d18e6e4d8a8:180151 1805 493
# "151.253.124.9, 10.254.69.145" 2023-09-01 09:08:03 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW
POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:85b6aa3b-d536-43cd-acfb-ba43272a4195:209482 2086 493
# "151.253.124.9, 10.254.69.149" 2023-09-01 08:01:36 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.113 APIGW:db76309d-ce90-4c9c-82ea-0bba2bd5a88f:175911 318 493
# "151.253.124.9, 10.254.69.151" 2023-09-01 08:05:22 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:d1b20ced-2298-45bd-8a7a-420d2d1632b3:209616 4048 493
# "151.253.124.9, 10.254.69.155" 2023-09-01 08:19:07 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:45628cff-d024-4a58-a658-c5d0c7a13ef9:171743 4129 493
# "151.253.124.9, 10.254.69.152" 2023-09-01 08:44:22 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:a18c72f3-6556-4fcd-9511-c95e693d6bd6:180130 15747 493
# "151.253.124.9, 10.254.69.147" 2023-09-01 08:45:40 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:7bb70e31-1448-47dd-af1b-fad670b906b5:176680 19915 493
# "151.253.124.9, 10.254.69.150" 2023-09-01 08:56:37 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:d2234bfd-c7ad-43d5-9a63-e5027a0648fc:209483 1129 493
# "151.253.124.9, 10.254.69.152" 2023-09-01 09:26:30 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:6d2a57e8-dac6-4418-be12-ea2af0dda66d:171934 875 493
# "151.253.124.9, 10.254.69.148" 2023-09-01 09:27:49 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:40479061-f96a-4ff5-958e-252166ccc5f7:176825 4420 493
# "151.253.124.9, 10.254.69.148" 2023-09-01 09:33:55 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:b4b64236-95c9-48f2-bb7e-39ee445208f3:217938 1265 493
# "151.253.124.9, 10.254.69.147" 2023-09-01 09:41:17 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:7b0b8323-f678-4223-92fd-b651bbd8f870:175203 10438 493
# "151.253.124.9, 10.254.69.150" 2023-09-01 09:41:30 POST /soap/custom/ADDA_ADC_TAMM_ADCustomsGenericServices 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:1163bab1-01f9-473a-8e72-f9ccf7baadae:178625 533 493
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_CommonSRQuery
# Count of 200 responses: 173
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_QCC_V2_SendFoodSampleService
# Count of 200 responses: 224
# Count of Non-200 responses: 1
# Non-200 responses:
# "10.80.1.251, 10.254.69.149" 2023-09-01 01:32:56 POST /soap/passThrough/ADDA_ADFCA_QCC_V2_SendFoodSampleService 500 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:ffda9a18-fab1-4a58-be4d-6985a72d81af:209593 47855 622
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_ProductQuery
# Count of 200 responses: 289
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_GetMandatoryDocs
# Count of 200 responses: 278
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_CPC.rs:CPCRequestByUAEIDPS/getRequestList
# Count of 200 responses: 2508
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADAFSA_MAQTA_SubmitCustomsDeclaration
# Count of 200 responses: 96
# Count of Non-200 responses: 1
# Non-200 responses:
# "10.33.3.6, 10.254.69.151" 2023-09-01 01:34:31 POST /soap/passThrough/ADDA_ADAFSA_MAQTA_SubmitCustomsDeclaration 500 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:8afc8e8e-45b9-40ac-92a7-5d1317d6e9e2:176684 30089 622
# ------------------------------
# URL: /restv2/ADDA_DCD.rs:SocialCare_PS/socialcare
# Count of 200 responses: 20
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_DED_CompanyRegistration
# Count of 200 responses: 11
# Count of Non-200 responses: 2
# Non-200 responses:
# "10.113.0.28, 10.254.69.145" 2023-09-01 07:21:54 POST /soap/passThrough/ADDA_ADFCA_DED_CompanyRegistration 500 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:a355e53d-c164-4613-af32-bda2887f06c9:171825 229072 582
# "10.113.0.28, 10.254.69.147" 2023-09-01 09:42:47 POST /soap/passThrough/ADDA_ADFCA_DED_CompanyRegistration 500 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW
POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:175e6c65-4b52-46ea-b7ef-58e7e0688059:209486 3085 72
# "10.11.14.69, 10.254.69.152" 2023-09-01 07:00:21 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.113 APIGW:b4fed7a4-f300-492c-bf06-0db20c31e65d:178658 10902 72
# "10.11.14.69, 10.254.69.145" 2023-09-01 07:00:32 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.113 APIGW:1363f4e8-41bb-439a-8122-5dc82b26a239:181331 1327 72
# "10.11.14.69, 10.254.69.148" 2023-09-01 07:00:30 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.81 APIGW:ff703cf6-fb0c-41cc-8204-e6963cec6b42:175212 3100 72
# "10.11.14.69, 10.254.69.157" 2023-09-01 07:00:37 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.113 APIGW:481c2090-229a-4455-bdc9-4365aa2627ec:175920 688 72
# "10.11.14.69, 10.254.69.148" 2023-09-01 07:00:34 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.65 APIGW:fd575275-3b7d-4691-af5f-ebc0328907bc:209484 8727 72
# "10.11.14.69, 10.254.69.151" 2023-09-01 03:00:23 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.97 APIGW:9309c7fb-d60a-4962-9326-fed6b52af596:172233 3464 72
# "10.11.14.69, 10.254.69.151" 2023-09-01 07:00:26 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:dd675e8b-db07-41f5-bd27-42d493e659b9:171852 2187 72
# "10.11.14.69, 10.254.69.154" 2023-09-01 07:00:28 POST /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_Application/OPAGETResults/OPAGETResults 400 https://adda-msr-svc-cip:5543 192.168.32.49 APIGW:4313f21e-b086-4879-ba6a-0186bdf9a149:175166 867 72
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_MasterDataQuery
# Count of 200 responses: 40
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_ImportRequest
# Count of 200 responses: 27
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_QCC_GetTestResults
# Count of 200 responses: 6
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADQCC_ADWEA_AdweaLimsService
# Count of 200 responses: 9
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADQCC_ADM_ADMLimsServiceV2
# Count of 200 responses: 55
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_FoodRegistration
# Count of 200 responses: 8
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_CreateAppointment
# Count of 200 responses: 5
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_TransferShipment
# Count of 200 responses: 3
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_GetInvoiceDetails
# Count of 200 responses: 9
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_MAQTA_PaymentForinvoice
# Count of 200 responses: 3
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADAFSA_ATLP_TrackResponseStatus
# Count of 200 responses: 12
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_ADQCC.rs:QCCVISService_PS/QCCVIS/masterData/getOnlineStores
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_ADQCC.rs:QCCVISService_PS/QCCVIS/masterData/getSubCategory
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_QCC_GetTestResultsDocs
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_HAAD_FoodPoisoningService
# Count of 200 responses: 6
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_ADQCC.rs:SmartServices_PS/personnel/certificate/detail
# Count of 200 responses: 2
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_ADQCC.rs:QCCVISService_PS/QCCVIS/masterData/getCategory
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADFCA_DMT_FarmsOwnershipChangeService
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/passThrough/ADDA_ADAFSA_MAQTA_ExportHealthCertificatePPService
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /restv2/ADDA_ADAFSA.rs:MobileApplicationPS/GBL_ADAFSA_MOB_GET_Application/InspectionKwonledge/InspectionKwonledge
# Count of 200 responses: 1
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/custom/ADDA_TAMM_ADP_TrafficProfile_2_0
# Count of 200 responses: 152886
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/custom/ADDA_TAMM_ADP_TicketServices_2_0
# Count of 200 responses: 4419
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/custom/ADDA_TAMM_ADP_AccidentServices_1_0
# Count of 200 responses: 3066
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
# URL: /soap/custom/ADDA_TAMM_ADP_VehicleServices_2_0
# Count of 200 responses: 62
# Count of Non-200 responses: 0
# Non-200 responses:
# ------------------------------
